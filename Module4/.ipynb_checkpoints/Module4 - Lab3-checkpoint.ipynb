# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module4- Lab3

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# .. your code here ..
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets/kidney_disease.csv', delimiter=',')
df.head()
df.drop(['id', 'classification', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'], axis=1, inplace=True)
df.dropna(axis=0, inplace=True)
df.reset_index(inplace=True)
df.head()
# Out:
#    index   age    bp     sg   al   su    bgr     bu   sc    sod  pot  hemo  \
# 0      3  48.0  70.0  1.005  4.0  0.0  117.0   56.0  3.8  111.0  2.5  11.2
# 1      5  60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.1  142.0  3.2  12.2
# 2      9  53.0  90.0  1.020  2.0  0.0   70.0  107.0  7.2  114.0  3.7   9.5
# 3     11  63.0  70.0  1.010  3.0  0.0  380.0   60.0  2.7  131.0  4.2  10.8
# 4     12  68.0  70.0  1.015  3.0  1.0  208.0   72.0  2.1  138.0  5.8   9.7
#
#   pcv     wc   rc
# 0  32   6700  3.9
# 1  39   7800  4.4
# 2  29  12100  3.7
# 3  32   4500  3.8
# 4  28  12200  3.4

# %%
df.dtypes
# Out:
# index      int64
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv       object
# wc        object
# rc        object
# dtype: object

# %%
df.pcv = pd.to_numeric(df.pcv, errors='coerce')
df.wc = pd.to_numeric(df.wc, errors='coerce')
df.rc = pd.to_numeric(df.rc, errors='coerce')
df.head()
# Out:
#    index   age    bp     sg   al   su    bgr     bu   sc    sod  pot  hemo  \
# 0      3  48.0  70.0  1.005  4.0  0.0  117.0   56.0  3.8  111.0  2.5  11.2
# 1      5  60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.1  142.0  3.2  12.2
# 2      9  53.0  90.0  1.020  2.0  0.0   70.0  107.0  7.2  114.0  3.7   9.5
# 3     11  63.0  70.0  1.010  3.0  0.0  380.0   60.0  2.7  131.0  4.2  10.8
# 4     12  68.0  70.0  1.015  3.0  1.0  208.0   72.0  2.1  138.0  5.8   9.7
#
#    pcv     wc   rc
# 0   32   6700  3.9
# 1   39   7800  4.4
# 2   29  12100  3.7
# 3   32   4500  3.8
# 4   28  12200  3.4

# %%
df.dtypes
# Out:
# index      int64
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv        int64
# wc         int64
# rc       float64
# dtype: object
